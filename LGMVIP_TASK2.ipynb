# %% [markdown]
# <a href="https://colab.research.google.com/github/ishika-s/LGM_Internship_2023/blob/main/LGMVIP_TASK2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#importing library
from google.colab.patches import cv2_imshow
import cv2

#reading the image
img=cv2.imread("girl.jpg")
#cv2_imshow(img)
#adjusting the siize opf the image
scale=20
width=int(img.shape[1] * scale/100)
height=int(img.shape[0] * scale/100)
dim=(width,height)
img2=cv2.resize(img,dim,interpolation=cv2.INTER_AREA)
cv2_imshow(img2)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F3917281410>

# %%
#converting into grey scale image
grayimg=cv2.cvtColor(img2,cv2.COLOR_BGR2GRAY)
cv2_imshow(grayimg)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7F39172788D0>

# %%
#inverting the image
img_invert = 255-grayimg
cv2_imshow(img_invert)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7F3917278E10>

# %%
##blurring the image
blurred_img = cv2.GaussianBlur(img_invert, (21, 21), 0)
cv2_imshow(blurred_img)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7F3917282A90>

# %%
#inverting the blurred image
blurred_invert = 255-blurred_img
cv2_imshow(blurred_invert)
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7F3917283DD0>

# %%
#the required pencil sketch
sketch = cv2.divide(grayimg, blurred_invert, scale=240.0)
cv2_imshow(sketch)
#final output
# Out:
# <PIL.Image.Image image mode=L size=400x400 at 0x7F39172826D0>

# %%
cv2_imshow(img2),cv2_imshow(sketch)
# Out:
# <PIL.Image.Image image mode=RGB size=400x400 at 0x7F391620E110>
# <PIL.Image.Image image mode=L size=400x400 at 0x7F3917281A90>
# (None, None)
